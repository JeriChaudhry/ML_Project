# %% [markdown]
# ## Assignment List (80 points)
# **Make sure you excute every cell in order, and reserve the outputs of every cell.**
# 1. Transform and plot image. (15 points)
# 2. Data loading. (10 points)
# 3. Train the baseline model and plot the learning curve. (15 points)
#
# 4. Comparison and analysis (20 points)
#     * Compare the training results of 5, 20, and 50 epochs.
#     * Use `torch.optim.Adam()` with a learning rate of 0.001 as the optimizer.
#     * Try a different data_transform function
# 5. Double the number of hidden units in your model and train it for 20 epochs, what happens to the results? (10 points)
# 6. Make a prediction on your own custom image of pizza/steak/sushi (you could even download one from the internet) and share your prediction. (10 points)
#     * Does the model you trained get it right?
#     * If not, what do you think you could do to improve it?
#
# ## Advanced options (20 points)
# **Make sure you excute every cell in order, and reserve the outputs of every cell.**
# - A1: Train a complicated model on the dataset (ResNet18) (10 points) \
#     **Remenber to resize the image data and recall dataloader**.
# - A2: Compare the performance of a simple model (provided by the template) and the complicated model. (5 points)
#       Plot learning curves in the same figure axes
# - A3: Usage of git version control (5 points)
#       Git add, git commit, git log, insert a screenshot within this notebook
#
# ### Deadline: 11.59 pm 16/01/2023
# ### Submit a rar/zip folder to brightspace under the unit of **Machine Learning for Media Production**

# %% [markdown]
# ## 0. Importing PyTorch and setting up device-agnostic code

# %%
import torch
from torch import nn

# Note: this notebook requires torch >= 1.10.0
# Setup device-agnostic code
device = "cuda" if torch.cuda.is_available() else "cpu"
torch.__version__, device
# Out:
# ('1.12.1+cu102', 'cuda')

# %% [markdown]
# ## 1. Get data
# [Food101 dataset](https://data.vision.ee.ethz.ch/cvl/datasets_extra/food-101/) is popular computer vision benchmark as it contains 1000 images of 101 different kinds of foods, totaling 101,000 images (75,750 train and 25,250 test).
# In this assignment, only 3 classes are used to form a small classification dataset, it contains pizza, steak and sushi.
# And instead of 1,000 images per class, ervey image class only has 100 images(10%).

# %%
import requests
import zipfile
from pathlib import Path

# Setup path to data folder
data_path = Path("data/")
image_path = data_path / "pizza_steak_sushi"

# If the image folder doesn't exist, download it and prepare it... 
if image_path.is_dir():
    print(f"{image_path} directory exists.")
else:
    print(f"Did not find {image_path} directory, creating one...")
    image_path.mkdir(parents=True, exist_ok=True)
    
    # Download pizza, steak, sushi data
    with open(data_path / "pizza_steak_sushi.zip", "wb") as f:
        request = requests.get("https://github.com/lizhiqihhh/AIM-MLWorkshop/raw/main/pizza_steak_sushi.zip")
        print("Downloading pizza, steak, sushi data...")
        f.write(request.content)

    # Unzip pizza, steak, sushi data
    with zipfile.ZipFile(data_path / "pizza_steak_sushi.zip", "r") as zip_ref:
        print("Unzipping pizza, steak, sushi data...") 
        zip_ref.extractall(image_path)
# Out:
# data/pizza_steak_sushi directory exists.

# %%
# Setup train and testing paths
train_dir = image_path / "train"
test_dir = image_path / "test"

train_dir, test_dir
# Out:
# (PosixPath('data/pizza_steak_sushi/train'),
#  PosixPath('data/pizza_steak_sushi/test'))

# %% [markdown]
# ## Task 1
#
# 1. Transform training dataset and testing dataset.
# 2. Plot images

# %% [markdown]
# ## 1.1 Transforming data

# %%
# import libraries and packages
import torch
from torch.utils.data import DataLoader
from torchvision import datasets, transforms

# %%
# Write transform for image
data_transform = transforms.Compose([
# Step 1: Resize the images to 64x64 # Resize the images to 64x64x3 (64 height, 64 width, 3 color channels)

    transforms.Resize([64,64]),
    
# Step 2: Turn the image into a torch.Tensor # converts all pixel values from 0-255 to be between 0-1  

    transforms.ToTensor(),
    
# Step 3: RandomHorizontalFlip---Flip the images randomly on the horizontal p = probability of flip, 0.5 = 50% chance 

    transforms.RandomHorizontalFlip(p=0.5)
    
])

# %%
#transforms

# %%
# Use ImageFolder to create dataset(s)
from torchvision import datasets
train_data = datasets.ImageFolder(root=train_dir , # root should be the target folder of images
                                  transform=data_transform, # transform should be a set of transform functions to perform on images
                                  target_transform=None) # transforms to perform on labels (if necessary)

test_data = datasets.ImageFolder(root=test_dir, # it should be the folder of test data 
                                 transform=data_transform) # same with transform applied to train_data

print(f"Train data:\n{train_data}\nTest data:\n{test_data}")
# Out:
# Train data:
# Dataset ImageFolder
#     Number of datapoints: 225
#     Root location: data/pizza_steak_sushi/train
#     StandardTransform
# Transform: Compose(
#                Resize(size=[64, 64], interpolation=bilinear, max_size=None, antialias=None)
#                ToTensor()
#                RandomHorizontalFlip(p=0.5)
#            )
# Test data:
# Dataset ImageFolder
#     Number of datapoints: 75
#     Root location: data/pizza_steak_sushi/test
#     StandardTransform
# Transform: Compose(
#                Resize(size=[64, 64], interpolation=bilinear, max_size=None, antialias=None)
#                ToTensor()
#                RandomHorizontalFlip(p=0.5)
#            )

# %%
# Use ImageFolder to create dataset(s)
from torchvision import datasets

train_data = datasets.ImageFolder(root=train_dir, 
                                  transform=data_transform, 
                                  target_transform=None)

test_data = datasets.ImageFolder(root=test_dir, 
                                 transform=data_transform) 

print(f"Train data:\n{train_data}\nTest data:\n{test_data}")
# Out:
# Train data:
# Dataset ImageFolder
#     Number of datapoints: 225
#     Root location: data/pizza_steak_sushi/train
#     StandardTransform
# Transform: Compose(
#                Resize(size=[64, 64], interpolation=bilinear, max_size=None, antialias=None)
#                ToTensor()
#                RandomHorizontalFlip(p=0.5)
#            )
# Test data:
# Dataset ImageFolder
#     Number of datapoints: 75
#     Root location: data/pizza_steak_sushi/test
#     StandardTransform
# Transform: Compose(
#                Resize(size=[64, 64], interpolation=bilinear, max_size=None, antialias=None)
#                ToTensor()
#                RandomHorizontalFlip(p=0.5)
#            )

# %%
len(train_data), len(test_data)
# Out:
# (225, 75)

# %% [markdown]
# ## 1.2 Plot the transformed image
# `Plot_imgs` and `plot_transformed_images` are defined in plot.py, complete the contents in plot.py

# %%
from pathlib import Path
from plot import Plot_imgs

# Setup path to data folder
data_path = Path("data/")
image_path = data_path / "pizza_steak_sushi"

# Plot an image using matplotlib
# Please complete the plot.py before use this plotting function
Plot_imgs(image_path)

# %%
from plot import plot_transformed_images
image_path_list = list(image_path.glob("*/*/*.jpg"))
plot_transformed_images(image_path_list, 
                        transform=data_transform, 
                        n=7)

# %%
# Get class names as a list
class_names = train_data.classes
# Try index on the `train_data` and `test_data` `Dataset`'s to find samples and their target labels.
image, label = train_data[0][0], train_data[0][1]
# Print the shape/content/datatype of img and label
print(f" shape: {image.shape} | n content: {image}\n |  datatype: {image.dtype}")
print(f"<label>) shape: {torch.tensor(label).shape} | <label> content: {label} | <label> datatype: {torch.tensor(label).dtype}")
# Out:
#  shape: torch.Size([3, 64, 64]) | n content: tensor([[[0.1176, 0.1216, 0.1255,  ..., 0.0980, 0.1020, 0.1137],
#          [0.1294, 0.1294, 0.1294,  ..., 0.0980, 0.0980, 0.1059],
#          [0.1333, 0.1333, 0.1333,  ..., 0.0941, 0.0980, 0.1020],
#          ...,
#          [0.1686, 0.1647, 0.1686,  ..., 0.1255, 0.1098, 0.1098],
#          [0.1686, 0.1647, 0.1686,  ..., 0.1098, 0.0941, 0.0863],
#          [0.1647, 0.1647, 0.1686,  ..., 0.0980, 0.0863, 0.0863]],
#
#         [[0.0588, 0.0588, 0.0588,  ..., 0.0745, 0.0706, 0.0745],
#          [0.0627, 0.0627, 0.0627,  ..., 0.0745, 0.0706, 0.0706],
#          [0.0706, 0.0706, 0.0706,  ..., 0.0745, 0.0745, 0.0706],
#          ...,
#          [0.2392, 0.2392, 0.2510,  ..., 0.1373, 0.1333, 0.1255],
#          [0.2314, 0.2392, 0.2510,  ..., 0.1255, 0.1176, 0.1098],
#          [0.2275, 0.2353, 0.2431,  ..., 0.1137, 0.1059, 0.1020]],
#
#         [[0.0196, 0.0196, 0.0196,  ..., 0.0902, 0.0902, 0.0941],
#          [0.0196, 0.0157, 0.0196,  ..., 0.0902, 0.0863, 0.0902],
#          [0.0196, 0.0157, 0.0157,  ..., 0.0902, 0.0902, 0.0902],
#          ...,
#          [0.1804, 0.1882, 0.1961,  ..., 0.1490, 0.1333, 0.1294],
#          [0.1804, 0.1843, 0.1922,  ..., 0.1255, 0.1137, 0.1098],
#          [0.1765, 0.1804, 0.1843,  ..., 0.1059, 0.1020, 0.1059]]])
#  |  datatype: torch.float32
# <label>) shape: torch.Size([]) | <label> content: 0 | <label> datatype: torch.int64

# %%
import matplotlib.pyplot as plt
from PIL import Image
image_permute = image.permute(1, 2, 0)

# Print out different shapes (before and after permute)
print(f"Original shape: {image.shape} -> [color_channels, height, width]")
print(f"Image permute shape: {image_permute.shape} -> [height, width, color_channels]")


# ---------------Plot the permuted image-------------
plt.figure()
plt.imshow(image_permute)
# ---------------End of code------------------------

plt.axis("off")
plt.title(class_names[label], fontsize=23)
# Out:
# Original shape: torch.Size([3, 64, 64]) -> [color_channels, height, width]
# Image permute shape: torch.Size([64, 64, 3]) -> [height, width, color_channels]
# Text(0.5, 1.0, 'pizza')

# %% [markdown]
# ## 1.3 Turn loaded images into `DataLoader`'s

# %% [markdown]
# ## Task 2: Turn train and test Datasets into DataLoaders (10 points)

# %%
from torch.utils.data import DataLoader
my_train_dataloader = DataLoader(dataset = train_data, batch_size = 7, shuffle = True) # shuffle training data

my_test_dataloader = DataLoader(dataset = test_data, batch_size = 7, shuffle = False) # don't usually need to shuffle testing data

my_train_dataloader, my_test_dataloader
# Out:
# (<torch.utils.data.dataloader.DataLoader at 0x7fa394472e80>,
#  <torch.utils.data.dataloader.DataLoader at 0x7fa394285730>)

# %%
# Load a batch of images in the training dataset
image, label = next(iter(my_train_dataloader))

print(f"Image shape: {image.shape} -> [batch_size, color_channels, height, width]")
print(f"Label shape: {label.shape}")
# Out:
# Image shape: torch.Size([7, 3, 64, 64]) -> [batch_size, color_channels, height, width]
# Label shape: torch.Size([7])

# %% [markdown]
# `display_random_images` is defined in plot.py, please complete the contents in `plot.py`

# %%
# Display random images from Dataset
from plot import display_random_images
display_random_images(train_data, 
                      n=8, 
                      classes=class_names,
                      seed=None)

# %% [markdown]
# ## Task 3 Model_0 training
# ### Task 3.1 Train the baseline model TinyVGG

# %%
from TinyVGG import TinyVGG # import the model from TinyVGG.py
torch.manual_seed(42)

# --------------Initialize the TinyVGG model--------------
'''
    Parameters: input_shape
                hidden_units
                output_shape
'''

model_0 = TinyVGG(input_shape = 3, hidden_units = 10, output_shape = 3).to(device) 

# -------------------  End of code -----------------------

model_0 # Print the model info here!
# Out:
# TinyVGG(
#   (conv_block_1): Sequential(
#     (0): Conv2d(3, 10, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(10, 10, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv_block_2): Sequential(
#     (0): Conv2d(10, 10, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(10, 10, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv_block_3): Sequential(
#     (0): Conv2d(10, 10, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(10, 10, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=640, out_features=3, bias=True)
#   )
# )

# %%
# 1. Get a batch of images and labels from the DataLoader
image_batch, label_batch = next(iter(my_train_dataloader))

# 2. Get a single image from the batch and unsqueeze the image so its shape fits the model
image_single, label_single = image_batch[0].unsqueeze(dim=0), label_batch[0]
print(f"Single image shape: {image_single.shape}\n")

# 3. Perform a forward pass on a single image
model_0.eval()
with torch.inference_mode():
    pred = model_0(image_single.to(device))
    
# 4. Print out what's happening and convert model logits -> pred probs -> pred label
print(f"Output logits:\n{pred}\n")
print(f"Output prediction probabilities:\n{torch.softmax(pred, dim=1)}\n")
print(f"Output prediction label:\n{torch.argmax(torch.softmax(pred, dim=1), dim=1)}\n")
print(f"Actual label:\n{label_single}")
# Out:
# Single image shape: torch.Size([1, 3, 64, 64])
#
# Output logits:
# tensor([[ 0.0213,  0.0190, -0.0162]], device='cuda:0')
#
# Output prediction probabilities:
# tensor([[0.3377, 0.3370, 0.3253]], device='cuda:0')
#
# Output prediction label:
# tensor([0], device='cuda:0')
#
# Actual label:
# 0

# %%
# Load the training function from TinyVGG.py
from TinyVGG import train
# Set random seeds
torch.manual_seed(42) 
torch.cuda.manual_seed(42)

# Set number of epochs
NUM_EPOCHS = 5

# Setup loss function and optimizer
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(params=model_0.parameters(), lr=0.001)

# Start the timer
from timeit import default_timer as timer 
start_time = timer()

# ------------------------- Train model_0 --------------------------

# Fill in the parentheses with parameters needed in the train function
model_0_results = train(model = model_0,
                        train_dataloader = my_train_dataloader,
                        test_dataloader = my_test_dataloader,
                        optimizer = optimizer,
                        loss_fn = loss_fn,
                        epochs = NUM_EPOCHS                        
)


# -------------------------  End of code  --------------------------
# End the timer and print out how long it took
end_time = timer()
print(f"Total training time: {end_time-start_time:.3f} seconds")
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# Epoch: 1 | train_loss: 1.1047 | train_acc: 0.3030 | test_loss: 1.0956 | test_acc: 0.4286
# Epoch: 2 | train_loss: 1.0995 | train_acc: 0.3333 | test_loss: 1.0979 | test_acc: 0.3247
# Epoch: 3 | train_loss: 1.0988 | train_acc: 0.3636 | test_loss: 1.0987 | test_acc: 0.3247
# Epoch: 4 | train_loss: 1.0993 | train_acc: 0.3377 | test_loss: 1.1016 | test_acc: 0.3247
# Epoch: 5 | train_loss: 1.0986 | train_acc: 0.3550 | test_loss: 1.1006 | test_acc: 0.3766
# Total training time: 6.046 seconds

# %% [markdown]
# ### Task 3.2: Plot the loss curves of Model_0
#
# From the print outs of our `model_0` training, it didn't look like it did too well.
#
# Create a function to plot the values in the `model_0_results` dictionary.

# %%
from typing import Tuple, Dict, List

def plot_loss_curves(results: Dict[str, List[float]]):
    """Plots training curves of a results dictionary.

    Args:
        results (dict): dictionary containing list of values, e.g.
            {"train_loss": [...],
             "train_acc": [...],
             "test_loss": [...],
             "test_acc": [...]}
    """
    
    # Get the loss values of the results dictionary (training and test)
    train_loss = results['train_loss']
    test_loss = results['test_loss']

    # Get the accuracy values of the results dictionary (training and test)
    train_accuracy = results['train_acc']
    test_accuracy = results['test_acc']

    # Figure out how many epochs there were
    epochs = range(len(results['train_loss']))

    # Setup a plot 
    plt.figure(figsize=(15, 7))

    # --------------- Complete the following lines --------------
    # Plot loss, please include label, title, and legend in the figure
    plt.subplot(1, 2, 1)
    plt.plot(epochs, train_loss)   # plot epochs, train_loss
    plt.plot(epochs, test_loss)   # plot epochs, test_loss
    plt.title('Train & Test Losses')
    plt.xlabel('Num of Epochs')
    plt.legend(['Train Loss', 'Test Loss'])
    
    # Plot accuracy
    plt.subplot(1, 2, 2)
    plt.plot(epochs, train_accuracy) # plot epochs, train_accuracy, add label
    plt.plot(epochs, test_accuracy) # plot epochs, test_accuracy, add label
    plt.title('Train & Test Accuracy')
    plt.xlabel('Num of Epochs')
    plt.legend(['Train Accuracy','Test Accuracy'])
    # ---------------------- End of codes -----------------------

# %%
plot_loss_curves(model_0_results)

# %% [markdown]
# `torchinfo` comes with a `summary()` method that takes a PyTorch model as well as an `input_shape` and returns what happens as a tensor moves through your model.

# %%
try: 
    import torchinfo
except:
    # !pip install torchinfo
    import torchinfo
    
from torchinfo import summary
summary(model_0, input_size=[1, 3, 64, 64]) # do a test pass through of an example input size
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# TinyVGG                                  [1, 3]                    --
# ├─Sequential: 1-1                        [1, 10, 32, 32]           --
# │    └─Conv2d: 2-1                       [1, 10, 64, 64]           280
# │    └─ReLU: 2-2                         [1, 10, 64, 64]           --
# │    └─Conv2d: 2-3                       [1, 10, 64, 64]           910
# │    └─ReLU: 2-4                         [1, 10, 64, 64]           --
# │    └─MaxPool2d: 2-5                    [1, 10, 32, 32]           --
# ├─Sequential: 1-2                        [1, 10, 16, 16]           --
# │    └─Conv2d: 2-6                       [1, 10, 32, 32]           910
# │    └─ReLU: 2-7                         [1, 10, 32, 32]           --
# │    └─Conv2d: 2-8                       [1, 10, 32, 32]           910
# │    └─ReLU: 2-9                         [1, 10, 32, 32]           --
# │    └─MaxPool2d: 2-10                   [1, 10, 16, 16]           --
# ├─Sequential: 1-3                        [1, 10, 8, 8]             --
# │    └─Conv2d: 2-11                      [1, 10, 16, 16]           910
# │    └─ReLU: 2-12                        [1, 10, 16, 16]           --
# │    └─Conv2d: 2-13                      [1, 10, 16, 16]           910
# │    └─ReLU: 2-14                        [1, 10, 16, 16]           --
# │    └─MaxPool2d: 2-15                   [1, 10, 8, 8]             --
# ├─Sequential: 1-4                        [1, 3]                    --
# │    └─Flatten: 2-16                     [1, 640]                  --
# │    └─Linear: 2-17                      [1, 3]                    1,923
# ==========================================================================================
# Total params: 6,753
# Trainable params: 6,753
# Non-trainable params: 0
# Total mult-adds (M): 7.21
# ==========================================================================================
# Input size (MB): 0.05
# Forward/backward pass size (MB): 0.86
# Params size (MB): 0.03
# Estimated Total Size (MB): 0.94
# ==========================================================================================

# %% [markdown]
# ## Task 4: Comparison and analysis

# %% [markdown]
# ### Task 4.1 Try different epochs

# %%
# Train for 5 epochs
torch.manual_seed(42)
torch.cuda.manual_seed(42)

# create a new instance of TinyVGG model
model_e_5 = TinyVGG(input_shape = 3, hidden_units = 10, output_shape = 3).to(device)

loss_fn=nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model_e_5.parameters(), lr=0.001)

model_e_5_results = train(model = model_e_5,
                          train_dataloader = my_train_dataloader,
                          test_dataloader = my_test_dataloader,
                          optimizer = optimizer,
                          loss_fn = loss_fn,
                          epochs = 5
)
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# Epoch: 1 | train_loss: 1.1041 | train_acc: 0.3074 | test_loss: 1.0943 | test_acc: 0.4286
# Epoch: 2 | train_loss: 1.0995 | train_acc: 0.3160 | test_loss: 1.1048 | test_acc: 0.3636
# Epoch: 3 | train_loss: 1.1037 | train_acc: 0.2338 | test_loss: 1.0975 | test_acc: 0.4286
# Epoch: 4 | train_loss: 1.0998 | train_acc: 0.3203 | test_loss: 1.0940 | test_acc: 0.3247
# Epoch: 5 | train_loss: 1.1015 | train_acc: 0.3377 | test_loss: 1.0985 | test_acc: 0.3247

# %%
# Train for 20 epochs
torch.manual_seed(42)
torch.cuda.manual_seed(42)

model_e_20 = TinyVGG(input_shape = 3, hidden_units = 10, output_shape = 3).to(device)

loss_fn=nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model_e_20.parameters(), lr=0.001)

model_e_20_results = train(model = model_e_20,
                          train_dataloader = my_train_dataloader,
                          test_dataloader = my_test_dataloader,
                          optimizer = optimizer,
                          loss_fn = loss_fn,
                          epochs = 20
)
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch: 1 | train_loss: 1.1040 | train_acc: 0.3074 | test_loss: 1.0946 | test_acc: 0.4286
# Epoch: 2 | train_loss: 1.0994 | train_acc: 0.3247 | test_loss: 1.1048 | test_acc: 0.3506
# Epoch: 3 | train_loss: 1.1035 | train_acc: 0.2381 | test_loss: 1.0983 | test_acc: 0.4286
# Epoch: 4 | train_loss: 1.1009 | train_acc: 0.3290 | test_loss: 1.0926 | test_acc: 0.4286
# Epoch: 5 | train_loss: 1.1013 | train_acc: 0.3463 | test_loss: 1.1008 | test_acc: 0.3247
# Epoch: 6 | train_loss: 1.0991 | train_acc: 0.2944 | test_loss: 1.1006 | test_acc: 0.2987
# Epoch: 7 | train_loss: 1.0982 | train_acc: 0.3463 | test_loss: 1.1052 | test_acc: 0.2468
# Epoch: 8 | train_loss: 1.1013 | train_acc: 0.3247 | test_loss: 1.1080 | test_acc: 0.2468
# Epoch: 9 | train_loss: 1.0987 | train_acc: 0.3247 | test_loss: 1.1009 | test_acc: 0.2468
# Epoch: 10 | train_loss: 1.0992 | train_acc: 0.2900 | test_loss: 1.0977 | test_acc: 0.4286
# Epoch: 11 | train_loss: 1.0978 | train_acc: 0.3247 | test_loss: 1.0983 | test_acc: 0.2468
# Epoch: 12 | train_loss: 1.0921 | train_acc: 0.3896 | test_loss: 1.0975 | test_acc: 0.2779
# Epoch: 13 | train_loss: 1.0439 | train_acc: 0.4459 | test_loss: 1.0897 | test_acc: 0.3636
# Epoch: 14 | train_loss: 1.0541 | train_acc: 0.4675 | test_loss: 1.0291 | test_acc: 0.5221
# Epoch: 15 | train_loss: 0.9701 | train_acc: 0.5714 | test_loss: 1.0516 | test_acc: 0.4338
# Epoch: 16 | train_loss: 0.9267 | train_acc: 0.5758 | test_loss: 1.0282 | test_acc: 0.4442
# Epoch: 17 | train_loss: 0.9278 | train_acc: 0.5758 | test_loss: 0.9964 | test_acc: 0.4052
# Epoch: 18 | train_loss: 0.8498 | train_acc: 0.6017 | test_loss: 1.0014 | test_acc: 0.4182
# Epoch: 19 | train_loss: 0.8244 | train_acc: 0.6494 | test_loss: 1.0878 | test_acc: 0.4130
# Epoch: 20 | train_loss: 0.8002 | train_acc: 0.6667 | test_loss: 1.0442 | test_acc: 0.4519

# %%
# Train for 50 epochs
torch.manual_seed(42)
torch.cuda.manual_seed(42)

model_e_50 = TinyVGG(input_shape = 3, hidden_units = 10, output_shape = 3).to(device)

loss_fn=nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model_e_50.parameters(), lr=0.001)

model_e_50_results = train(model = model_e_50,
                          train_dataloader = my_train_dataloader,
                          test_dataloader = my_test_dataloader,
                          optimizer = optimizer,
                          loss_fn = loss_fn,
                          epochs = 50
    
)
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# Epoch: 1 | train_loss: 1.1041 | train_acc: 0.3074 | test_loss: 1.0942 | test_acc: 0.4286
# Epoch: 2 | train_loss: 1.0995 | train_acc: 0.3160 | test_loss: 1.1048 | test_acc: 0.3506
# Epoch: 3 | train_loss: 1.1037 | train_acc: 0.2294 | test_loss: 1.0981 | test_acc: 0.4286
# Epoch: 4 | train_loss: 1.1003 | train_acc: 0.3290 | test_loss: 1.0981 | test_acc: 0.3247
# Epoch: 5 | train_loss: 1.0995 | train_acc: 0.3377 | test_loss: 1.0999 | test_acc: 0.3247
# Epoch: 6 | train_loss: 1.0990 | train_acc: 0.3377 | test_loss: 1.1004 | test_acc: 0.3247
# Epoch: 7 | train_loss: 1.0982 | train_acc: 0.2857 | test_loss: 1.1048 | test_acc: 0.3247
# Epoch: 8 | train_loss: 1.1011 | train_acc: 0.3203 | test_loss: 1.1081 | test_acc: 0.2468
# Epoch: 9 | train_loss: 1.0989 | train_acc: 0.3247 | test_loss: 1.1010 | test_acc: 0.2468
# Epoch: 10 | train_loss: 1.0997 | train_acc: 0.2814 | test_loss: 1.0970 | test_acc: 0.3740
# Epoch: 11 | train_loss: 1.0986 | train_acc: 0.3117 | test_loss: 1.0985 | test_acc: 0.3247
# Epoch: 12 | train_loss: 1.0984 | train_acc: 0.2987 | test_loss: 1.0980 | test_acc: 0.3247
# Epoch: 13 | train_loss: 1.0971 | train_acc: 0.3766 | test_loss: 1.0957 | test_acc: 0.4156
# Epoch: 14 | train_loss: 1.0617 | train_acc: 0.4329 | test_loss: 1.0110 | test_acc: 0.4078
# Epoch: 15 | train_loss: 0.9797 | train_acc: 0.5714 | test_loss: 1.0436 | test_acc: 0.4338
# Epoch: 16 | train_loss: 0.9502 | train_acc: 0.5281 | test_loss: 1.0093 | test_acc: 0.4961
# Epoch: 17 | train_loss: 0.8796 | train_acc: 0.6190 | test_loss: 1.0301 | test_acc: 0.5403
# Epoch: 18 | train_loss: 0.8111 | train_acc: 0.6494 | test_loss: 1.0294 | test_acc: 0.4182
# Epoch: 19 | train_loss: 0.8003 | train_acc: 0.6667 | test_loss: 0.9860 | test_acc: 0.5221
# Epoch: 20 | train_loss: 0.7373 | train_acc: 0.6537 | test_loss: 1.0905 | test_acc: 0.5299
# Epoch: 21 | train_loss: 0.7673 | train_acc: 0.6797 | test_loss: 0.9896 | test_acc: 0.4597
# Epoch: 22 | train_loss: 0.7316 | train_acc: 0.6667 | test_loss: 1.0545 | test_acc: 0.4857
# Epoch: 23 | train_loss: 0.6965 | train_acc: 0.7359 | test_loss: 1.0464 | test_acc: 0.4468
# Epoch: 24 | train_loss: 0.6591 | train_acc: 0.7359 | test_loss: 1.0353 | test_acc: 0.4987
# Epoch: 25 | train_loss: 0.6607 | train_acc: 0.7056 | test_loss: 0.9896 | test_acc: 0.4519
# Epoch: 26 | train_loss: 0.6278 | train_acc: 0.7403 | test_loss: 1.1616 | test_acc: 0.4078
# Epoch: 27 | train_loss: 0.5949 | train_acc: 0.7532 | test_loss: 1.0809 | test_acc: 0.4727
# Epoch: 28 | train_loss: 0.6259 | train_acc: 0.7229 | test_loss: 1.0032 | test_acc: 0.4779
# Epoch: 29 | train_loss: 0.5756 | train_acc: 0.7749 | test_loss: 1.2037 | test_acc: 0.4649
# Epoch: 30 | train_loss: 0.5020 | train_acc: 0.7965 | test_loss: 1.1492 | test_acc: 0.4779
# Epoch: 31 | train_loss: 0.5403 | train_acc: 0.8139 | test_loss: 1.0200 | test_acc: 0.5532
# Epoch: 32 | train_loss: 0.5051 | train_acc: 0.8225 | test_loss: 1.1285 | test_acc: 0.4961
# Epoch: 33 | train_loss: 0.4971 | train_acc: 0.8052 | test_loss: 1.1008 | test_acc: 0.5351
# Epoch: 34 | train_loss: 0.4109 | train_acc: 0.8442 | test_loss: 1.2981 | test_acc: 0.5247
# Epoch: 35 | train_loss: 0.4209 | train_acc: 0.8225 | test_loss: 1.2461 | test_acc: 0.4987
# Epoch: 36 | train_loss: 0.3714 | train_acc: 0.8528 | test_loss: 1.2270 | test_acc: 0.5922
# Epoch: 37 | train_loss: 0.4572 | train_acc: 0.8355 | test_loss: 1.1908 | test_acc: 0.4909
# Epoch: 38 | train_loss: 0.3104 | train_acc: 0.9048 | test_loss: 1.6678 | test_acc: 0.4519
# Epoch: 39 | train_loss: 0.3192 | train_acc: 0.8485 | test_loss: 1.6069 | test_acc: 0.6000
# Epoch: 40 | train_loss: 0.3524 | train_acc: 0.8615 | test_loss: 1.6473 | test_acc: 0.4468
# Epoch: 41 | train_loss: 0.2831 | train_acc: 0.9004 | test_loss: 2.1802 | test_acc: 0.5091
# Epoch: 42 | train_loss: 0.2751 | train_acc: 0.8918 | test_loss: 1.8358 | test_acc: 0.6000
# Epoch: 43 | train_loss: 0.1571 | train_acc: 0.9481 | test_loss: 1.8591 | test_acc: 0.5688
# Epoch: 44 | train_loss: 0.2047 | train_acc: 0.9091 | test_loss: 2.1928 | test_acc: 0.4909
# Epoch: 45 | train_loss: 0.2696 | train_acc: 0.8831 | test_loss: 1.8750 | test_acc: 0.5039
# Epoch: 46 | train_loss: 0.2149 | train_acc: 0.9221 | test_loss: 2.3136 | test_acc: 0.5351
# Epoch: 47 | train_loss: 0.1517 | train_acc: 0.9264 | test_loss: 2.3523 | test_acc: 0.5662
# Epoch: 48 | train_loss: 0.2101 | train_acc: 0.9091 | test_loss: 2.4197 | test_acc: 0.4701
# Epoch: 49 | train_loss: 0.2220 | train_acc: 0.9091 | test_loss: 2.2934 | test_acc: 0.5299
# Epoch: 50 | train_loss: 0.1684 | train_acc: 0.9264 | test_loss: 2.4469 | test_acc: 0.5481

# %% [markdown]
# ### Compare: Print the differences

# %%
import pandas as pd 
model_compare_1 = pd.DataFrame(model_e_5_results)
model_compare_2 = pd.DataFrame(model_e_20_results)
model_compare_3 = pd.DataFrame(model_e_50_results)

model_compare_1[4:5]
# Out:
#    train_loss  train_acc  test_loss  test_acc
# 4    1.101528   0.337662   1.098481  0.324675

# %%
model_compare_2[19:20]
# Out:
#     train_loss  train_acc  test_loss  test_acc
# 19    0.800161   0.666667    1.04424  0.451948

# %%
model_compare_3[49:50]
# Out:
#     train_loss  train_acc  test_loss  test_acc
# 49    0.168422   0.926407   2.446864  0.548052

# %% [markdown]
# ### Analysis: What you find and how to improve model_0's performance?

# %% [markdown]
# **Your answer**:
#
# We find that just as the number of epochs increases, as do both the test & train accuracies, and simultaneously we find the train loss decreasing.
# The only oddity we find is that though the test loss decreases from model_compare_1 to model_compare_2, it increases for model_compare_3; I believe this is due to overfitting.
#
# Model_0's performance would improve increasing the epochs and/or reducing the hidden units.

# %% [markdown]
# ### Task 4.2 Try different data transform functions

# %%
import os
BATCH_SIZE = 32
NUM_WORKERS = os.cpu_count()

torch.manual_seed(42)

# --------- Create training transform with TrivialAugment ---------
# TrivialAugment: Tuning-Free Yet State-of-the-Art Data Augmentation (source:https://arxiv.org/abs/2103.10158)
train_transform_trivial_augment = transforms.Compose([
    # Resize
    transforms.Resize([64,64]),
    
    # RandomHorizontalFlip
    transforms.RandomHorizontalFlip(p=0.5),

    # TrivialAugment
    transforms.TrivialAugmentWide(fill=20),
    

    # ToTensor
    transforms.ToTensor()
    
])

train_data_augmented = datasets.ImageFolder(train_dir, transform=train_transform_trivial_augment)

my_train_dataloader_augmented = DataLoader(dataset = train_data_augmented, batch_size = 5, shuffle = True)
my_test_dataloader_simple = DataLoader(dataset = test_data, batch_size = 5, shuffle = False)
# ---------------------- End of code ----------------------

my_train_dataloader_augmented, my_test_dataloader_simple
# Out:
# (<torch.utils.data.dataloader.DataLoader at 0x7fa3600424f0>,
#  <torch.utils.data.dataloader.DataLoader at 0x7fa360042370>)

# %%
# Create model_1 and send it to the target device
torch.manual_seed(42)
model_1 = TinyVGG(input_shape = 3, hidden_units = 10, output_shape = 3).to(device)
model_1 # print model_1
# Out:
# TinyVGG(
#   (conv_block_1): Sequential(
#     (0): Conv2d(3, 10, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(10, 10, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv_block_2): Sequential(
#     (0): Conv2d(10, 10, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(10, 10, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv_block_3): Sequential(
#     (0): Conv2d(10, 10, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(10, 10, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=640, out_features=3, bias=True)
#   )
# )

# %%
# Set random seeds
torch.manual_seed(42) 
torch.cuda.manual_seed(42)

# Set number of epochs
NUM_EPOCHS = 5

# Setup loss function and optimizer
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(params=model_1.parameters(), lr=0.001)

# Start the timer
from timeit import default_timer as timer 
start_time = timer()

# ------------------------- Train model_1 ----------------------------
# Fill in the parentheses with parameters needed in the train function
model_1_results = train(model = model_1,
                        train_dataloader = my_train_dataloader_augmented,
                        test_dataloader = my_test_dataloader_simple,
                        optimizer = optimizer,
                        loss_fn = loss_fn,
                        epochs = NUM_EPOCHS
)

# ------------------------- End of model_1 ---------------------------
# End the timer and print out how long it took
end_time = timer()
print(f"Total training time: {end_time-start_time:.3f} seconds")
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# Epoch: 1 | train_loss: 1.1049 | train_acc: 0.2978 | test_loss: 1.0957 | test_acc: 0.4133
# Epoch: 2 | train_loss: 1.1004 | train_acc: 0.2756 | test_loss: 1.0958 | test_acc: 0.4133
# Epoch: 3 | train_loss: 1.1001 | train_acc: 0.3156 | test_loss: 1.0998 | test_acc: 0.3333
# Epoch: 4 | train_loss: 1.0993 | train_acc: 0.3467 | test_loss: 1.0978 | test_acc: 0.3333
# Epoch: 5 | train_loss: 1.0997 | train_acc: 0.3467 | test_loss: 1.0988 | test_acc: 0.3333
# Total training time: 6.477 seconds

# %% [markdown]
# ## Task 5: Double the number of hidden units in your model and train it for 20 epochs

# %%
# Double the number of hidden units and train for 20 epochs
torch.manual_seed(42)
torch.cuda.manual_seed(42)

model_2 = TinyVGG(input_shape = 3, hidden_units = 20, output_shape = 3).to(device) # use 20 hidden units instead of 10

loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model_2.parameters(), lr=0.001)

model_2_results = train(model = model_2, 
                        train_dataloader = my_train_dataloader_augmented,
                        test_dataloader = my_test_dataloader_simple,
                        optimizer = optimizer,
                        loss_fn = loss_fn,
                        epochs = 20              # training for 20 epochs
)
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch: 1 | train_loss: 1.1019 | train_acc: 0.3200 | test_loss: 1.0975 | test_acc: 0.3333
# Epoch: 2 | train_loss: 1.1003 | train_acc: 0.3467 | test_loss: 1.1006 | test_acc: 0.2533
# Epoch: 3 | train_loss: 1.0995 | train_acc: 0.3378 | test_loss: 1.0976 | test_acc: 0.3333
# Epoch: 4 | train_loss: 1.0976 | train_acc: 0.4000 | test_loss: 1.0656 | test_acc: 0.5600
# Epoch: 5 | train_loss: 1.0966 | train_acc: 0.3867 | test_loss: 1.0863 | test_acc: 0.3600
# Epoch: 6 | train_loss: 1.0346 | train_acc: 0.5156 | test_loss: 1.0877 | test_acc: 0.5067
# Epoch: 7 | train_loss: 1.0382 | train_acc: 0.4844 | test_loss: 0.9919 | test_acc: 0.5200
# Epoch: 8 | train_loss: 1.0305 | train_acc: 0.4978 | test_loss: 1.0220 | test_acc: 0.4533
# Epoch: 9 | train_loss: 0.9681 | train_acc: 0.5333 | test_loss: 1.0368 | test_acc: 0.4933
# Epoch: 10 | train_loss: 1.0012 | train_acc: 0.5156 | test_loss: 0.9600 | test_acc: 0.4933
# Epoch: 11 | train_loss: 0.9593 | train_acc: 0.5156 | test_loss: 0.9796 | test_acc: 0.4267
# Epoch: 12 | train_loss: 0.9196 | train_acc: 0.6044 | test_loss: 1.0206 | test_acc: 0.4800
# Epoch: 13 | train_loss: 0.9049 | train_acc: 0.5733 | test_loss: 1.1518 | test_acc: 0.4533
# Epoch: 14 | train_loss: 0.9509 | train_acc: 0.5644 | test_loss: 0.9600 | test_acc: 0.4800
# Epoch: 15 | train_loss: 0.9013 | train_acc: 0.5644 | test_loss: 1.0051 | test_acc: 0.4667
# Epoch: 16 | train_loss: 0.9161 | train_acc: 0.5867 | test_loss: 1.0617 | test_acc: 0.4800
# Epoch: 17 | train_loss: 0.9168 | train_acc: 0.5822 | test_loss: 0.9702 | test_acc: 0.5333
# Epoch: 18 | train_loss: 0.9089 | train_acc: 0.5644 | test_loss: 1.0604 | test_acc: 0.4800
# Epoch: 19 | train_loss: 0.9608 | train_acc: 0.5422 | test_loss: 0.9884 | test_acc: 0.5067
# Epoch: 20 | train_loss: 0.8956 | train_acc: 0.6044 | test_loss: 1.0309 | test_acc: 0.4267

# %% [markdown]
# ## Task 6: Make prediction on a custom image based on model_2

# %%
# Read a custom image from img_path and represent it as a tensor datatype
import torchvision

image_path = './data/'
custom_image = image_path + "Image2.jpg"
image = torchvision.io.read_image(custom_image)

# %%
# Make a prediction on the image, put model_2 in eval mode
model_2.eval()
with torch.inference_mode():
  # Get image pixels into float + between 0 and 1
  image = image / 255.
    
  # -------------------- Complete the following lines ---------------------
  # Resize image to 64x64
  resize = transforms.Resize([64,64])
  image = resize(image)
  print('Resized image shape: \n',image.shape)

  # Turn image in single batch and pass to target device
  # add an additional dimension to img using unsqueeze()

  batch_image = image.unsqueeze(0).to(device) # modify this line!!!
  print('Add batch dim: \n', batch_image.shape)

  # Predict on image
  y_pred_logit = model_2(batch_image) 
  # ---------------------   End of code    ------------------------------
    
  # Convert pred logit to pred label
  pred_label = torch.argmax(y_pred_logit, dim=1)

# Plot the image and prediction
plt.imshow(image.permute(1, 2, 0))
plt.title(f"Pred label: {class_names[pred_label]}")
plt.axis(False)
# Out:
# Resized image shape:
#  torch.Size([3, 64, 64])
# Add batch dim:
#  torch.Size([1, 3, 64, 64])
# (-0.5, 63.5, 63.5, -0.5)

# %% [markdown]
# ### Analysis
# Does the model you trained get it right?
# If not, how to improve it?\
# **Your answer:**
#
# No, the model doesn't predict acurately, rather we find that the model keeps predicting incorrectly in favour of 'Pizza' label.
#
# Intially, the model was tested by introducing an image of a piece of Steak and the model returned the predict label:'Pizza'. We analyse that the shape of that steak was similar to a pizza slice, and the redish colour of the steak also resembles the top of a pizza.
# Similarly, now that we've changed the image to sushi (Image2), the model due to its overfitting, has incorrectly predicted the item as 'Pizza', perhaps due to finding similarity of colour in the image.
#
# This is due to the small size of the dataset the model was trained on, whereby anything that appears to resemble the shape of a Pizza, or contain similar over-riding colours; the model returns 'Pizza' as prediction.
#
# **In order to improve** our results, we can increase the number of epochs which will improve the prediction accuracy.
# In general, increasing the size of the train dataset will result in better performance, as will reducing the number of features, to avoid overfitting.

# %% [markdown]
# ## Advanced tasks
# ### A1: Train a complicated model (Use ResNet18 as an example) (10 points)

# %% [markdown]
# ### Read `Resnet18_pytorch.py` and complete the model file
# > If you finish `Resnet18_pytorch.py` correctly, run the following line will generate a vector with shape = ([1,3])

# %%
# %%bash
# python3.9 Resnet18_pytorch.py
# Out:
# torch.Size([1, 3])Output feature size.

# %%
from Resnet18_pytorch import ResNet, BasicBlock
torch.manual_seed(42)
model_resnet = ResNet(img_channels=3, num_layers=18, block=BasicBlock, num_classes=3).to(device)
model_resnet
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=3, bias=True)
# )

# %% [markdown]
# ### Preparing train dataloader and test dataloader

# %%
BATCH_SIZE=32
NUM_WORKERS=2
# ----- Complete the following transform functions -----
train_transform_augment = transforms.Compose([
    transforms.Resize([64,64]),
    transforms.ToTensor(),
    transforms.RandomHorizontalFlip(p=0.5) 
])
    

#  ----------------  End of code --------------------
train_data_augmented = datasets.ImageFolder(train_dir, transform=train_transform_augment)
train_dataloader_resnet = DataLoader(my_train_dataloader)

test_dataloader_simple = DataLoader(my_test_dataloader)

train_dataloader_resnet, my_test_dataloader
# Out:
# (<torch.utils.data.dataloader.DataLoader at 0x7fa394392220>,
#  <torch.utils.data.dataloader.DataLoader at 0x7fa394285730>)

# %% [markdown]
# #### Start training

# %%
# Set random seeds
torch.manual_seed(42) 
torch.cuda.manual_seed(42)

# Set number of epochs
NUM_EPOCHS = 5

# Setup loss function and optimizer
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(params=model_resnet.parameters(), lr=0.001)

# Start the timer
from timeit import default_timer as timer 
start_time = timer()

# Train model
model_resnet_results = train(model = model_resnet,
                          train_dataloader = my_train_dataloader,
                          test_dataloader = my_test_dataloader,
                          optimizer = optimizer,
                          loss_fn = loss_fn,
                          epochs = NUM_EPOCHS 
)

# End the timer and print out how long it took
end_time = timer()
print(f"Total training time: {end_time-start_time:.3f} seconds")
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# Epoch: 1 | train_loss: 1.1703 | train_acc: 0.4762 | test_loss: 1.4755 | test_acc: 0.4026
# Epoch: 2 | train_loss: 0.9309 | train_acc: 0.5541 | test_loss: 0.9659 | test_acc: 0.4779
# Epoch: 3 | train_loss: 0.8941 | train_acc: 0.5844 | test_loss: 1.0808 | test_acc: 0.4987
# Epoch: 4 | train_loss: 0.8459 | train_acc: 0.6494 | test_loss: 1.6995 | test_acc: 0.4208
# Epoch: 5 | train_loss: 0.8349 | train_acc: 0.6061 | test_loss: 1.5169 | test_acc: 0.3766
# Total training time: 8.281 seconds

# %% [markdown]
# ### A2: Compare model performance (5 points)
# Choose a previous model used in **Task 3** (model_0) or **Task 4** (model_1) to compare with ResNet18 model

# %%
from torchinfo import summary
summary(model_resnet, input_size=[1, 3, 224, 224]) # do a test pass through of an example input size
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# ResNet                                   [1, 3]                    --
# ├─Conv2d: 1-1                            [1, 64, 112, 112]         9,408
# ├─BatchNorm2d: 1-2                       [1, 64, 112, 112]         128
# ├─ReLU: 1-3                              [1, 64, 112, 112]         --
# ├─MaxPool2d: 1-4                         [1, 64, 56, 56]           --
# ├─Sequential: 1-5                        [1, 64, 56, 56]           --
# │    └─BasicBlock: 2-1                   [1, 64, 56, 56]           --
# │    │    └─Conv2d: 3-1                  [1, 64, 56, 56]           36,864
# │    │    └─BatchNorm2d: 3-2             [1, 64, 56, 56]           128
# │    │    └─ReLU: 3-3                    [1, 64, 56, 56]           --
# │    │    └─Conv2d: 3-4                  [1, 64, 56, 56]           36,864
# │    │    └─BatchNorm2d: 3-5             [1, 64, 56, 56]           128
# │    │    └─ReLU: 3-6                    [1, 64, 56, 56]           --
# │    └─BasicBlock: 2-2                   [1, 64, 56, 56]           --
# │    │    └─Conv2d: 3-7                  [1, 64, 56, 56]           36,864
# │    │    └─BatchNorm2d: 3-8             [1, 64, 56, 56]           128
# │    │    └─ReLU: 3-9                    [1, 64, 56, 56]           --
# │    │    └─Conv2d: 3-10                 [1, 64, 56, 56]           36,864
# │    │    └─BatchNorm2d: 3-11            [1, 64, 56, 56]           128
# │    │    └─ReLU: 3-12                   [1, 64, 56, 56]           --
# ├─Sequential: 1-6                        [1, 128, 28, 28]          --
# │    └─BasicBlock: 2-3                   [1, 128, 28, 28]          --
# │    │    └─Conv2d: 3-13                 [1, 128, 28, 28]          73,728
# │    │    └─BatchNorm2d: 3-14            [1, 128, 28, 28]          256
# │    │    └─ReLU: 3-15                   [1, 128, 28, 28]          --
# │    │    └─Conv2d: 3-16                 [1, 128, 28, 28]          147,456
# │    │    └─BatchNorm2d: 3-17            [1, 128, 28, 28]          256
# │    │    └─Sequential: 3-18             [1, 128, 28, 28]          8,448
# │    │    └─ReLU: 3-19                   [1, 128, 28, 28]          --
# │    └─BasicBlock: 2-4                   [1, 128, 28, 28]          --
# │    │    └─Conv2d: 3-20                 [1, 128, 28, 28]          147,456
# │    │    └─BatchNorm2d: 3-21            [1, 128, 28, 28]          256
# │    │    └─ReLU: 3-22                   [1, 128, 28, 28]          --
# │    │    └─Conv2d: 3-23                 [1, 128, 28, 28]          147,456
# │    │    └─BatchNorm2d: 3-24            [1, 128, 28, 28]          256
# │    │    └─ReLU: 3-25                   [1, 128, 28, 28]          --
# ├─Sequential: 1-7                        [1, 256, 14, 14]          --
# │    └─BasicBlock: 2-5                   [1, 256, 14, 14]          --
# │    │    └─Conv2d: 3-26                 [1, 256, 14, 14]          294,912
# │    │    └─BatchNorm2d: 3-27            [1, 256, 14, 14]          512
# │    │    └─ReLU: 3-28                   [1, 256, 14, 14]          --
# │    │    └─Conv2d: 3-29                 [1, 256, 14, 14]          589,824
# │    │    └─BatchNorm2d: 3-30            [1, 256, 14, 14]          512
# │    │    └─Sequential: 3-31             [1, 256, 14, 14]          33,280
# │    │    └─ReLU: 3-32                   [1, 256, 14, 14]          --
# │    └─BasicBlock: 2-6                   [1, 256, 14, 14]          --
# │    │    └─Conv2d: 3-33                 [1, 256, 14, 14]          589,824
# │    │    └─BatchNorm2d: 3-34            [1, 256, 14, 14]          512
# │    │    └─ReLU: 3-35                   [1, 256, 14, 14]          --
# │    │    └─Conv2d: 3-36                 [1, 256, 14, 14]          589,824
# │    │    └─BatchNorm2d: 3-37            [1, 256, 14, 14]          512
# │    │    └─ReLU: 3-38                   [1, 256, 14, 14]          --
# ├─Sequential: 1-8                        [1, 512, 7, 7]            --
# │    └─BasicBlock: 2-7                   [1, 512, 7, 7]            --
# │    │    └─Conv2d: 3-39                 [1, 512, 7, 7]            1,179,648
# │    │    └─BatchNorm2d: 3-40            [1, 512, 7, 7]            1,024
# │    │    └─ReLU: 3-41                   [1, 512, 7, 7]            --
# │    │    └─Conv2d: 3-42                 [1, 512, 7, 7]            2,359,296
# │    │    └─BatchNorm2d: 3-43            [1, 512, 7, 7]            1,024
# │    │    └─Sequential: 3-44             [1, 512, 7, 7]            132,096
# │    │    └─ReLU: 3-45                   [1, 512, 7, 7]            --
# │    └─BasicBlock: 2-8                   [1, 512, 7, 7]            --
# │    │    └─Conv2d: 3-46                 [1, 512, 7, 7]            2,359,296
# │    │    └─BatchNorm2d: 3-47            [1, 512, 7, 7]            1,024
# │    │    └─ReLU: 3-48                   [1, 512, 7, 7]            --
# │    │    └─Conv2d: 3-49                 [1, 512, 7, 7]            2,359,296
# │    │    └─BatchNorm2d: 3-50            [1, 512, 7, 7]            1,024
# │    │    └─ReLU: 3-51                   [1, 512, 7, 7]            --
# ├─AdaptiveAvgPool2d: 1-9                 [1, 512, 1, 1]            --
# ├─Linear: 1-10                           [1, 3]                    1,539
# ==========================================================================================
# Total params: 11,178,051
# Trainable params: 11,178,051
# Non-trainable params: 0
# Total mult-adds (G): 1.81
# ==========================================================================================
# Input size (MB): 0.60
# Forward/backward pass size (MB): 39.74
# Params size (MB): 44.71
# Estimated Total Size (MB): 85.05
# ==========================================================================================

# %% [markdown]
# ### Plot the train_loss and test_loss of model_resnet and a previous model using subplot function

# %%
import pandas as pd
model_1_df = pd.DataFrame(model_1_results) # Or model_1

model_resnet_df = pd.DataFrame(model_resnet_results)
model_1_df, model_resnet_df
# Out:
# (   train_loss  train_acc  test_loss  test_acc
#  0    1.104946   0.297778   1.095656  0.413333
#  1    1.100431   0.275556   1.095781  0.413333
#  2    1.100094   0.315556   1.099799  0.333333
#  3    1.099289   0.346667   1.097789  0.333333
#  4    1.099708   0.346667   1.098775  0.333333,
#     train_loss  train_acc  test_loss  test_acc
#  0    1.170302   0.476190   1.475504  0.402597
#  1    0.930918   0.554113   0.965890  0.477922
#  2    0.894084   0.584416   1.080751  0.498701
#  3    0.845899   0.649351   1.699550  0.420779
#  4    0.834877   0.606061   1.516868  0.376623)

# %%
# ------ Complete subplot functions in the following lines -------
plt.figure(figsize=(15, 10))

# Get number of epochs
epochs = range(len(model_1_df))

# Plot train loss with label, title, legend
plt.subplot (2, 2, 1)

plt.plot (epochs, model_1_df["train_loss"])
plt.plot (epochs, model_resnet_df["train_loss"])
plt.xlabel('Epochs')          
plt.title('Train Loss Representation')

plt.legend(['Previous Model' , 'ResNet Model'])



# Plot test loss
plt.subplot(2, 2, 2)

plt.plot (epochs, model_1_df["test_loss"])
plt.plot (epochs, model_resnet_df["test_loss"])
plt.xlabel('Epochs')          
plt.title('Test Loss Representation')

plt.legend(['Previous Model' , 'ResNet Model'])



# Plot train accuracy
plt.subplot(2, 2, 3)
 
plt.plot (epochs, model_1_df["train_acc"])
plt.plot (epochs, model_resnet_df["train_acc"])
plt.xlabel('Epochs')          
plt.title('Train Accuracy Representation')

plt.legend(['Previous Model' , 'ResNet Model'])



# Plot test accuracy
plt.subplot(2, 2, 4)

plt.plot (epochs, model_1_df["test_acc"])
plt.plot (epochs, model_resnet_df["test_acc"])
plt.xlabel('Epochs')          
plt.title('Test Accuracy Representation')

plt.legend(['Previous Model' , 'ResNet Model'])

# %% [markdown]
# ### A3: Git version control (5 points)
# Please insert an image in the cell to show your git log

# %% [markdown]
# ### Git version control advices
# 1. Create a remote repo, upload this notebote to the repo\
#    **Take a screenshot of the inital status**
# 2. git clone (ssh link of the repo)
# 3. Make some modifications to the files
# 4. git add .
# 5. git commit -m "leave some message here"
# 6. git push
# 7. git log
# 8. check the remote repo, **Take a screenshot after git push operations**

# %%
from IPython.display import Image

# %%
Image("git pull.png",width=994,height=655)

# %%
Image("git merge.png")

# %%
Image("git push steps.png")

# %%
Image("before.png",width=800,height=800)

# %%
Image("after.png")

# %%
Image("gitlog.png")
